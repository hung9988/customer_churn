# %%
import numpy as np


params = np.load('params.npz', allow_pickle=True)
data = np.load('dataset_one_hot.npz', allow_pickle=True)
W= params['W']
b= params['b']
X_validation = data['X_validation']
y_validation = data['y_validation']

def sigmoid(Z):
    return 1/1+np.exp(-Z)

def logistic_regression(W,X,b):
   
    Z = np.dot(W,X)+b

    return sigmoid(Z)

# def predict(W,X,b):
#     A = logistic_regression(W,X,b)
#     return np.round(A)

# def accuracy(W,X,b,y):
#     m = y.shape
#     p = predict(W,X,b)
#     return np.sum((p == y)/m)

# print(accuracy(W,X_validation,b,y_validation))




for i in range(200):
    Z= logistic_regression(W,X_validation[i,:],b)
# Out:
# (73,) (73,)
# [655.74122588]
# (73,) (73,)
# [809.72617456]
# (73,) (73,)
# [733.04939843]
# (73,) (73,)
# [606.66184924]
# (73,) (73,)
# [606.73044566]
# (73,) (73,)
# [683.76308229]
# (73,) (73,)
# [769.19090359]
# (73,) (73,)
# [710.04142718]
# (73,) (73,)
# [790.95347339]
# (73,) (73,)
# [659.14892319]
# (73,) (73,)
# [683.79217697]
# (73,) (73,)
# [800.44758366]
# (73,) (73,)
# [760.25239708]
# (73,) (73,)
# [724.14043183]
# (73,) (73,)
# [707.28912403]
# (73,) (73,)
# [600.45355587]
# (73,) (73,)
# [857.97303711]
# (73,) (73,)
# [585.05121372]
# (73,) (73,)
# [708.37077702]
# (73,) (73,)
# [701.7470655]
# (73,) (73,)
# [799.88499056]
# (73,) (73,)
# [645.32679671]
# (73,) (73,)
# [741.52280295]
# (73,) (73,)
# [661.24911716]
# (73,) (73,)
# [735.72641896]
# (73,) (73,)
# [677.20426375]
# (73,) (73,)
# [672.80777736]
# (73,) (73,)
# [762.39677617]
# (73,) (73,)
# [718.97687987]
# (73,) (73,)
# [756.75014878]
# (73,) (73,)
# [694.10628042]
# (73,) (73,)
# [751.41790369]
# ...

# %%
import numpy as np

A= np.array([1,2,3,4])
B= np.array([1,2,3,4])

print (np.dot(A,B))

print (A.shape)
print (B.shape)
# Out:
# 30
# (4,)
# (4,)

# %%
import numpy as np

data = np.load('dataset_one_hot.npz', allow_pickle=True)

X_validation = data['X_validation']

X_0_shape = X_validation[0, :].shape
weight_array = np.random.rand(*X_0_shape)
b = np.random.rand(1)

print(b)
print(weight_array.shape)
# Out:
# [0.85568793]
# (73,)
